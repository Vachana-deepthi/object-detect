# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()
# Out:
# fatal: cannot change to '/Users/konishbharathrajjonnalagadda/Desktop/UNH/Deep': No such file or directory
# YOLOv5 🚀 2023-12-7 Python-3.11.3 torch-2.1.0 CPU
# Setup complete ✅ (10 CPUs, 32.0 GB RAM, 93.0/460.4 GB disk)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="IZAclv1ZD99jdZRkpm81")
project = rf.workspace("roboflow-gw7yv").project("vehicles-openimages")
dataset = project.version(1).download("yolov5")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Vehicles-OpenImages-1 in yolov5pytorch:: 100%|

# %%
#!python train.py --img 640 --batch 16 --epochs 100 --data data.yaml --weights yolov5s.pt --cache

#model is trained in colab for 100 epochs and weights are extracted
from IPython.display import Image, display

# Specify the path to your image file
image_path = 'ss.jpg'

# Display the image
display(Image(filename=image_path))

# %%
# !python detect.py --weights last.pt --img 640 --conf 0.25 --source images
# Out:
# detect: weights=['last.pt'], source=images, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/Users/konishbharathrajjonnalagadda/Desktop/UNH/Deep': No such file or directory
# YOLOv5 🚀 2023-12-7 Python-3.11.3 torch-2.1.0 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7023610 parameters, 0 gradients, 15.8 GFLOPs
# image 1/5 /Users/konishbharathrajjonnalagadda/Desktop/UNH/Deep learning/final project/yolov5/images/00aaf0a0a9ee7e71_jpg.rf.KBCzX2HtZviBuQY9JDTQ.jpg: 640x640 1 Truck, 72.4ms
# ...

# %%
import os
from IPython.display import Image, display

def display_images_in_folder(folder_path, width=600):
    # Get a list of all files in the folder
    file_list = os.listdir(folder_path)

    # Filter out only the image files (you may need to adjust the file extensions)
    image_files = [file for file in file_list if file.lower().endswith(('.png', '.jpg', '.jpeg', '.gif'))]

    # Display each image
    for image_file in image_files:
        image_path = os.path.join(folder_path, image_file)
        display(Image(filename=image_path, width=width))

# Specify the folder path
exp2_folder_path = 'runs/detect/exp2/'

# Display images in the exp2 folder
display_images_in_folder(exp2_folder_path)
